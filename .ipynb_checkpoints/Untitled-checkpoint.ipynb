# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Load CSV
df = pd.read_csv("social_posts.csv")

# Function to extract tweet details from embed URL
def extract_tweet_data(embed_url):
    try:
        response = requests.get(embed_url)
        soup = BeautifulSoup(response.text, "html.parser")
        
        tweet_text = soup.find("p").text if soup.find("p") else "N/A"
        author = soup.find("span", {"class": "TweetAuthor-name"}).text if soup.find("span", {"class": "TweetAuthor-name"}) else "N/A"
        
        return {
            "text": tweet_text,
            "author": author
        }
    except Exception as e:
        return {
            "text": "Error",
            "author": str(e)
        }

# Apply extraction to first few rows (for demo)
results = df.head(5)["url"].apply(extract_tweet_data)
extracted_df = pd.DataFrame(results.tolist())
final_df = pd.concat([df.head(5).reset_index(drop=True), extracted_df], axis=1)

print(final_df)
# Out:
#   extraction_date platform                                                url  \
# 0      02-04-2025  Twitter  https://platform.twitter.com/embed/Tweet.html?...
# 1      02-04-2025  Twitter  https://platform.twitter.com/embed/Tweet.html?...
# 2      02-04-2025  Twitter  https://platform.twitter.com/embed/Tweet.html?...
# 3      02-04-2025  Twitter  https://platform.twitter.com/embed/Tweet.html?...
# 4      02-04-2025  Twitter  https://platform.twitter.com/embed/Tweet.html?...
#
#   text author
# 0  N/A    N/A
# 1  N/A    N/A
# 2  N/A    N/A
# 3  N/A    N/A
# 4  N/A    N/A

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime

def fetch_og_data(url):
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
        }
        response = requests.get(url, headers=headers, timeout=10)
        soup = BeautifulSoup(response.text, 'html.parser')

        def get_meta(property_name):
            tag = soup.find('meta', property=property_name)
            return tag['content'] if tag and tag.has_attr('content') else ''

        return {
            'url': url,
            'title': get_meta('og:title'),
            'description': get_meta('og:description'),
            'image': get_meta('og:image'),
            'site_name': get_meta('og:site_name')
        }

    except Exception as e:
        print(f"Failed to fetch: {url} -> {e}")
        return {
            'url': url,
            'title': '',
            'description': '',
            'image': '',
            'site_name': '',
            'error': str(e)
        }

# Load CSV with post URLs
csv_path = 'social_posts.csv'
df = pd.read_csv(csv_path)

# Extract OG metadata for each URL
results = [fetch_og_data(url) for url in df['url']]

# Merge with original CSV
og_df = pd.DataFrame(results)
merged_df = pd.concat([df, og_df.drop(columns='url')], axis=1)

# Save results
output_csv = f'post_metadata_{datetime.now().strftime("%Y%m%d")}.csv'
merged_df.to_csv(output_csv, index=False)

print(f"✅ Metadata extracted and saved to {output_csv}")
# Out:
# ✅ Metadata extracted and saved to post_metadata_20250722.csv

# %%
merged_df
# Out:
#    extraction_date  platform  \
# 0       02-04-2025   Twitter
# 1       02-04-2025   Twitter
# 2       02-04-2025   Twitter
# 3       02-04-2025   Twitter
# 4       02-04-2025   Twitter
# ..             ...       ...
# 89      02-04-2025  LinkedIn
# 90      02-04-2025  LinkedIn
# 91      02-04-2025  LinkedIn
# 92      02-04-2025  LinkedIn
# 93      02-04-2025  LinkedIn
#
#                                                   url  \
# 0   https://platform.twitter.com/embed/Tweet.html?...
# 1   https://platform.twitter.com/embed/Tweet.html?...
# 2   https://platform.twitter.com/embed/Tweet.html?...
# 3   https://platform.twitter.com/embed/Tweet.html?...
# 4   https://platform.twitter.com/embed/Tweet.html?...
# ..                                                ...
# 89  https://www.linkedin.com/embed/feed/update/urn...
# 90  https://www.linkedin.com/embed/feed/update/urn...
# 91  https://www.linkedin.com/embed/feed/update/urn...
# 92  https://www.linkedin.com/embed/feed/update/urn...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\envs\tf\lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~\anaconda3\envs\tf\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~\anaconda3\envs\tf\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# Headless Chrome
options = Options()
options.headless = True
driver = webdriver.Chrome(options=options)
email = "shrivathsavreddykotla@gmail.com"
password = "shri07$Chinnu"
csv_file = "social_posts.csv"

driver.get("https://linkedin.com/uas/login")
time.sleep(5)

username = driver.find_element(By.ID, "username")
username.send_keys(email)
pword = driver.find_element(By.ID, "password")
pword.send_keys(password)
driver.find_element(By.XPATH, "//button[@type='submit']").click()

# LinkedIn post URL
url = "https://www.linkedin.com/posts/woxsen-university_woxsen-woxsenuniversity-designschool-activity-7260856205340729345-KCMC"
driver.get(url)

# Wait for load
time.sleep(5)

# Extract post content (very basic)
try:
    post_text = driver.find_element("css selector", ".feed-shared-update-v2__description-wrapper").text
    print("Post Text:", post_text)
except:
    print("Could not extract post text.")

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 16
#      13 time.sleep(5)
#      15 username = driver.find_element(By.ID, "username")
# ---> 16 username.send_keys(self.email)
#      17 pword = driver.find_element(By.ID, "password")
#      18 pword.send_keys(self.password)
#
# NameError: name 'self' is not defined
